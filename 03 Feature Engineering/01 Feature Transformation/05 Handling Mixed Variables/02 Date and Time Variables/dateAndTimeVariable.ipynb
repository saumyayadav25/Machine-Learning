# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyayadav25/Machine-Learning/blob/main/03%20Feature%20Engineering/01%20Feature%20Transformation/05%20Handling%20Mixed%20Variables/02%20Date%20and%20Time%20Variables/dateAndTimeVariable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info() #by default date is object->need to change the datatype to date-time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# # Working with dates

# %%
# converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# ### Extract year

# %%
date['date_year'] = date['date'].dt.year
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year
# 872 2019-08-12         393        3      85       2019
# 751 2018-12-10        1603       16       1       2018
# 696 2019-03-19        6065       18       2       2019
# 488 2019-10-30        6663        4       1       2019
# 747 2018-08-06        2490        7       9       2018

# %% [markdown]
# ### Extract month

# %%
date['date_year'] = date['date'].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3         12
# 1 2018-08-15        3646       14     157          8
# 2 2018-10-23        1859       25       1         10
# 3 2019-08-17        7292       25       1          8
# 4 2019-01-06        4344       25       3          1

# %%
date['date_month_name'] = date['date'].dt.month_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month_name
# 0 2019-12-10        5628       25       3       2019        December
# 1 2018-08-15        3646       14     157       2018          August
# 2 2018-10-23        1859       25       1       2018         October
# 3 2019-08-17        7292       25       1       2019          August
# 4 2019-01-06        4344       25       3       2019         January

# %% [markdown]
# ### Extract Days

# %%
date['date_day'] = date['date'].dt.day
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month_name  date_day
# 0 2019-12-10        5628       25       3       2019        December        10
# 1 2018-08-15        3646       14     157       2018          August        15
# 2 2018-10-23        1859       25       1       2018         October        23
# 3 2019-08-17        7292       25       1       2019          August        17
# 4 2019-01-06        4344       25       3       2019         January         6

# %%
# day of week
date['date_dow'] = date['date'].dt.dayofweek
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month_name  \
# 0 2019-12-10        5628       25       3       2019        December
# 1 2018-08-15        3646       14     157       2018          August
# 2 2018-10-23        1859       25       1       2018         October
# 3 2019-08-17        7292       25       1       2019          August
# 4 2019-01-06        4344       25       3       2019         January
#
#    date_day  date_dow
# 0        10         1
# 1        15         2
# 2        23         1
# 3        17         5
# 4         6         6

# %%
# day of week - name
date['date_dow_name'] = date['date'].dt.day_name()
date.drop(columns = ['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_name  date_day  date_dow date_dow_name
# 0 2019-12-10       2019        December        10         1       Tuesday
# 1 2018-08-15       2018          August        15         2     Wednesday
# 2 2018-10-23       2018         October        23         1       Tuesday
# 3 2019-08-17       2019          August        17         5      Saturday
# 4 2019-01-06       2019         January         6         6        Sunday

# %%
# is weekend?
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)
date.drop(columns = ['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_name  date_day  date_dow date_dow_name  \
# 0 2019-12-10       2019        December        10         1       Tuesday
# 1 2018-08-15       2018          August        15         2     Wednesday
# 2 2018-10-23       2018         October        23         1       Tuesday
# 3 2019-08-17       2019          August        17         5      Saturday
# 4 2019-01-06       2019         January         6         6        Sunday
#
#    date_is_weekend
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1

# %% [markdown]
# ### Extract week of the year

# %%
date['date_week'] = date['date'].dt.isocalendar().week
date.drop(columns = ['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_name  date_day  date_dow date_dow_name  \
# 0 2019-12-10       2019        December        10         1       Tuesday
# 1 2018-08-15       2018          August        15         2     Wednesday
# 2 2018-10-23       2018         October        23         1       Tuesday
# 3 2019-08-17       2019          August        17         5      Saturday
# 4 2019-01-06       2019         January         6         6        Sunday
#
#    date_is_weekend  date_week
# 0                0         50
# 1                0         33
# 2                0         43
# 3                1         33
# 4                1          1

# %% [markdown]
# ###Extract Quarter

# %%
date['quarter'] = date['date'].dt.quarter
date.drop(columns = ['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_name  date_day  date_dow date_dow_name  \
# 0 2019-12-10       2019        December        10         1       Tuesday
# 1 2018-08-15       2018          August        15         2     Wednesday
# 2 2018-10-23       2018         October        23         1       Tuesday
# 3 2019-08-17       2019          August        17         5      Saturday
# 4 2019-01-06       2019         January         6         6        Sunday
#
#    date_is_weekend  date_week  quarter
# 0                0         50        4
# 1                0         33        3
# 2                0         43        4
# 3                1         33        3
# 4                1          1        1

# %% [markdown]
# ### Extract semester

# %%
date['semester'] = np.where(date['quarter'].isin([1,2]),1,2)
date.drop(columns = ['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_name  date_day  date_dow date_dow_name  \
# 0 2019-12-10       2019        December        10         1       Tuesday
# 1 2018-08-15       2018          August        15         2     Wednesday
# 2 2018-10-23       2018         October        23         1       Tuesday
# 3 2019-08-17       2019          August        17         5      Saturday
# 4 2019-01-06       2019         January         6         6        Sunday
#
#    date_is_weekend  date_week  quarter  semester
# 0                0         50        4         2
# 1                0         33        3         2
# 2                0         43        4         2
# 3                1         33        3         2
# 4                1          1        1         1

# %% [markdown]
# ### Extract Time elapsed between Dates

# %%
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2024, 8, 15, 6, 31, 31, 610741)

# %%
today - date['date']
# Out:
# 0     1710 days 06:24:42.976646
# 1     2192 days 06:24:42.976646
# 2     2123 days 06:24:42.976646
# 3     1825 days 06:24:42.976646
# 4     2048 days 06:24:42.976646
#                  ...
# 995   2138 days 06:24:42.976646
# 996   2079 days 06:24:42.976646
# 997   1927 days 06:24:42.976646
# 998   1992 days 06:24:42.976646
# 999   1766 days 06:24:42.976646
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      1710
# 1      2192
# 2      2123
# 3      1825
# 4      2048
#        ...
# 995    2138
# 996    2079
# 997    1927
# 998    1992
# 999    1766
# Name: date, Length: 1000, dtype: int64

# %%
# Months passed

# np.round((today - date['date']) / np.timedelta64(1, 'M'),0)

days_diff = (today - date['date']).dt.days
months_passed = np.round(days_diff / 30.44, 0)

months_passed
# Out:
# 0      56.0
# 1      72.0
# 2      70.0
# 3      60.0
# 4      67.0
#        ...
# 995    70.0
# 996    68.0
# 997    63.0
# 998    65.0
# 999    58.0
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# # Working with Time

# %%
# Converting to datetime datatype
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %% [markdown]
# ### Extract Time part

# %%
time['time'] = time['date'].dt.time
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %% [markdown]
# ### Time difference

# %%
today - time['date']
# Out:
# 0     3896 days 05:41:31.610741
# 1     3760 days 06:51:31.610741
# 2     4246 days 06:10:31.610741
# 3     3548 days 06:00:31.610741
# 4     3945 days 07:20:31.610741
#                  ...
# 995   4535 days 05:41:31.610741
# 996   3856 days 07:17:31.610741
# 997   4321 days 06:54:31.610741
# 998   4437 days 06:57:31.610741
# 999   3709 days 07:06:31.610741
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# in seconds
(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.366349e+08
# 1      3.248887e+08
# 2      3.668766e+08
# 3      3.065688e+08
# 4      3.408744e+08
#            ...
# 995    3.918445e+08
# 996    3.331847e+08
# 997    3.733593e+08
# 998    3.833819e+08
# 999    3.204832e+08
# Name: date, Length: 1000, dtype: float64

# %%
# in minutes
(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      5.610582e+06
# 1      5.414812e+06
# 2      6.114611e+06
# 3      5.109481e+06
# 4      5.681241e+06
#            ...
# 995    6.530742e+06
# 996    5.553078e+06
# 997    6.222655e+06
# 998    6.389698e+06
# 999    5.341387e+06
# Name: date, Length: 1000, dtype: float64

# %%
# in hours
(today - time['date'])/np.timedelta64(1,'h')
# Out:
# 0       93509.692114
# 1       90246.858781
# 2      101910.175447
# 3       85158.008781
# 4       94687.342114
#            ...
# 995    108845.692114
# 996     92551.292114
# 997    103710.908781
# 998    106494.958781
# 999     89023.108781
# Name: date, Length: 1000, dtype: float64
