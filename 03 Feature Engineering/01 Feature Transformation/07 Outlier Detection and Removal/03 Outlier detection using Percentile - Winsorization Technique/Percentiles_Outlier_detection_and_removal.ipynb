# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyayadav25/Machine-Learning/blob/main/03%20Feature%20Engineering/01%20Feature%20Transformation/07%20Outlier%20Detection%20and%20Removal/03%20Outlier%20detection%20using%20Percentile%20-%20Winsorization%20Technique/Percentiles_Outlier_detection_and_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(df['Height'])
# Out:
# /tmp/ipython-input-3945773010.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
upper_limit = df['Height'].quantile(0.99)
upper_limit
# Out:
# np.float64(74.7857900583366)

# %%
lower_limit = df['Height'].quantile(0.01)
lower_limit
# Out:
# np.float64(58.13441158671655)

# %%
new_df = df[(df['Height'] <= 74.78) & (df['Height'] >= 58.13)]

# %%
new_df['Height'].describe()
# Out:
# count    9799.000000
# mean       66.363507
# std         3.644267
# min        58.134496
# 25%        63.577147
# 50%        66.317899
# 75%        69.119859
# max        74.767447
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.distplot(new_df['Height'])
# Out:
# /tmp/ipython-input-1622920233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(new_df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %% [markdown]
# # Capping --> Winsorization

# %%
df['Height'] = np.where(df['Height'] >= upper_limit,
        upper_limit,
        np.where(df['Height'] <= lower_limit,
        lower_limit,
        df['Height']))

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
sns.distplot(df['Height'])
# Out:
# /tmp/ipython-input-3945773010.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>
